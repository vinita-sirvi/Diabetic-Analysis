# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the data presentin the tsv file 
df=pd.read_csv("diabetese.tsv", sep="\t")
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
# Lets find the average age of diabetic patients
mean_age = df['AGE'].mean()
print(f"mean age is :{mean_age}")
# Out:
# mean age is :48.51809954751131

# %%
# Variance 
var_age=df["AGE"].var()
print(f"variance in age : {var_age}")
# Out:
# variance in age : 171.84661043904742

# %%
# Standard deviation 
std_age=df["AGE"].std()
print(f"Standard Deviation :{std_age}")
# Out:
# Standard Deviation :13.109027822041092

# %%
# Boxplotting for the age
plt.figure(figsize=(2,6))
plt.boxplot(df["AGE"], showmeans=True)
plt.grid(color='gray', linestyle='dotted')
plt.xlabel("Age")
plt.ylabel("years")
plt.show()

# %%
#Boxplot for BMI
plt.figure(figsize=(6,2))
plt.boxplot(df['BMI'], vert=False, showmeans= True)
plt.grid(color='gray', linestyle='dotted')
plt.xlabel("value")
plt.ylabel("BMI")
plt.show()

# %%
#Boxplot for BP
plt.figure(figsize=(6,2))
plt.boxplot(df['BP'], vert=False, showmeans= True)
plt.grid(color='gray', linestyle='dotted')
plt.xlabel("value")
plt.ylabel("BP")
plt.show()

# %%
# I want to understand what age of patients are mstly diabetics

# we can create histogram for the same
df['AGE'].hist(bins=12)
plt.title("Age distribution of diabetic patients")
plt.xlabel("Age Range")
plt.ylabel("Count")
plt.show()

# %%
# I want to understand what age of patients are mstly diabetics

# we can create histogram for the same
df['BMI'].hist(bins=12)
plt.title("BMI distribution of diabetic patients")
plt.xlabel("BMI Range")
plt.ylabel("Count")
plt.show()

# %%
hours_studies=[2,3,1,4,2,5,4,6,3,5]
exam_score=[70,80,60,85,75,90,88,92,80,95]


plt.scatter(hours_studies, exam_score, color='blue', marker='o')

plt.xlabel("Hours studies")
plt.ylabel("Exam Score")
plt.title("Scatter plot: Hours studies Vs Exams scores")
plt.show()

# %%
plt.scatter(df['BMI'], df['Y'], color='blue')

plt.xlabel("BMI")
plt.ylabel("Disease progression")
plt.title("Scatter plot: BMI Vs Disease progression")
plt.show()

# %%
plt.scatter(df['S5'], df['Y'], color='blue')

plt.xlabel("S5 blood type")
plt.ylabel("Disease progression")
plt.title("Scatter plot: s% Vs Disease progression")
plt.show()
